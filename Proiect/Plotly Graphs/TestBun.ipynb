# %%
import pandas as pd
import numpy as np
import cufflinks as cf
import plotly as py
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
# %matplotlib inline

from plotly.offline import download_plotlyjs, init_notebook_mode,plot, iplot
init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
song_data = pd.read_csv("https://raw.githubusercontent.com/Lys4nder/SchoolDataset/main/song_data.csv",sep=';')
song_data.head()
# Out:
#                                nume         artist  vizualizari  \
# 0         STAY (with Justin Bieber)  The Kid LAROI     68764542
# 1  INDUSTRY BABY (with Jack Harlow)      Lil Nas X     43663527
# 2                        Bad Habits     Ed Sheeran     34182580
# 3                           Beggin'       Måneskin     32620597
# 4                         Hurricane     Kanye West     30609671
#
#          venituri     lansare    aparitie durata          gen            tara  \
# 0  343.822,71 USD  09.07.2021  02.09.2021   2:21          POP       Australia
# 1  218.317,64 USD  23.07.2021  02.09.2021   3:32  HIP-HOP/RAP             SUA
# 2  170.912,90 USD  11.06.2021  02.09.2021   3:32          POP  Marea Britanie
# 3  163.102,99 USD  08.12.2017  02.09.2021   3:31         ROCK          Italia
# 4  153.048,36 USD  08.08.2021  02.09.2021   4:03  HIP-HOP/RAP             SUA
#
#   colab
# 0    Da
# 1    Da
# 2    Nu
# 3    Nu
# 4    Nu

# %%
fig = px.pie(song_data, names="colab")
fig.show()
